# %% [markdown]
# - File is a named location on disk to store related information. It is
# used to permanently store data in a non-volatile memory (e.g. hard
# disk).
# - Since, random access memory (RAM) is volatile which loses its data when computer is turned off, we use files for future use of the data.
# - When we want to read from or write to a file we need to open it first. When we are done, it needs to be closed, so that resources that are tied with the file are freed.
# - Hence, in Python, a file operation takes place in the following order
# * Open a file
# * Read or write (perform operation)
# * Close the file

# %% [markdown]
# ##### Reading a file

# %%
# Filename: sample.txt
f = open('sample.txt')

# %%
f
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='UTF-8'>

# %% [markdown]
# In mode, we specify whether we want to read 'r', write 'w' or append 'a' to the file.

# %% [markdown]
# ![image.png](attachment:7d575985-5b06-41db-8843-b5206b7b6d51.png)

# %% [markdown]
# ##### readable() function

# %%
f.readable()
# Out:
# True

# %% [markdown]
# ##### readline() function

# %%
f.readline()
# Out:
# 'Hello Friends!\n'

# %%
f.readline()
# Out:
# 'How are you?\n'

# %%
f.readline()
# Out:
# 'Welcome to the world of Python Programming'

# %%
f.readline()
# Out:
# ''

# %%
f = open('sample.txt')

# %%
f.readline(10)
# Out:
# 'Hello Frie'

# %%
f.readline(5)
# Out:
# 'nds!\n'

# %%
f.readline(10)
# Out:
# 'How are yo'

# %% [markdown]
# ##### readlines() function

# %%
f = open('sample.txt')

# %%
data = f.readlines()

# %%
data
# Out:
# ['Hello Friends!\n',
#  'How are you?\n',
#  'Welcome to the world of Python Programming']

# %%
for line in data:
    print(line)
# Out:
# Hello Friends!
#
# How are you?
#
# Welcome to the world of Python Programming

# %%
for line in data:
    print(line.capitalize())
# Out:
# Hello friends!
#
# How are you?
#
# Welcome to the world of python programming

# %%
for line in data:
    print(line.title())
# Out:
# Hello Friends!
#
# How Are You?
#
# Welcome To The World Of Python Programming

# %% [markdown]
# ##### read() function

# %%
f = open('sample.txt')

# %%
text = f.read()

# %%
print(text)
# Out:
# Hello Friends!
# How are you?
# Welcome to the world of Python Programming

# %%
text.split()
# Out:
# ['Hello',
#  'Friends!',
#  'How',
#  'are',
#  'you?',
#  'Welcome',
#  'to',
#  'the',
#  'world',
#  'of',
#  'Python',
#  'Programming']

# %%
m = open('maharashtra.txt')

# %%
print(m.read())
# Out:
# महाराष्ट्र हे भारताच्या पश्चिम भागातले एक राज्य आहे. क्षेत्रफळाच्या दृष्टीने महाराष्ट्र भारतातील तिसरे व लोकसंख्येच्या बाबतीत दुसरे मोठे राज्य आहे. महाराष्ट्र हे भारताच्या सर्वांत विकसनशिल राज्यांपैकी एक आहे. महाराष्ट्र राज्याची सीमा गुजरात, मध्य प्रदेश, छत्तीसगढ, तेलंगणा, कर्नाटक, गोवा आणि दादरा आणि नगर-हवेली या केंद्रशासित प्रदेशांशी जोडलेली आहे. राज्याच्या पश्चिमेला अरबी समुद्राची ७२० कि.मी.ची किनारपट्टी आहे. जवळपास ११ कोटी लोकसंख्या असलेल्या महाराष्ट्राची राजधानी मुंबई आहे. मुंबईत साधारण १.८ कोटी लोक राहतात. नागपूर शहर महाराष्ट्राची उपराजधानी आहे. मध्ययुगीन महाराष्ट्र सातवाहन राजवंश राष्ट्रकूट राजवंश, पश्चिम चालुक्य, मुघल आणि मराठ्यांच्या साम्राज्याचा समावेश आहे. विस्तार १, १८, ८०९ चौरस मैल (३,०७, ७१३ चौरस किमी) असून, तो पश्चिम आणि कर्नाटक, तेलंगणा, गोवा, गुजरात, छत्तीसगड, मध्य प्रदेश आणि दादरा आणि नगर हवेली भारतीय राज्यांना अरबी समुद्र लागून आहे. महाराष्ट्राला जगद्गुरू संत तुकाराम, संत ज्ञानेश्र्वर, संत चोखामेळा, संत एकनाथ, संत नामदेव, संत गाडगेबाबा संत मुक्ताई यासारख्या अनेक मह
# ...

# %%
m = open('maharashtra.txt')
print(m.read().split())
# Out:
# ['महाराष्ट्र', 'हे', 'भारताच्या', 'पश्चिम', 'भागातले', 'एक', 'राज्य', 'आहे.', 'क्षेत्रफळाच्या', 'दृष्टीने', 'महाराष्ट्र', 'भारतातील', 'तिसरे', 'व', 'लोकसंख्येच्या', 'बाबतीत', 'दुसरे', 'मोठे', 'राज्य', 'आहे.', 'महाराष्ट्र', 'हे', 'भारताच्या', 'सर्वांत', 'विकसनशिल', 'राज्यांपैकी', 'एक', 'आहे.', 'महाराष्ट्र', 'राज्याची', 'सीमा', 'गुजरात,', 'मध्य', 'प्रदेश,', 'छत्तीसगढ,', 'तेलंगणा,', 'कर्नाटक,', 'गोवा', 'आणि', 'दादरा', 'आणि', 'नगर-हवेली', 'या', 'केंद्रशासित', 'प्रदेशांशी', 'जोडलेली', 'आहे.', 'राज्याच्या', 'पश्चिमेला', 'अरबी', 'समुद्राची', '७२०', 'कि.मी.ची', 'किनारपट्टी', 'आहे.', 'जवळपास', '११', 'कोटी', 'लोकसंख्या', 'असलेल्या', 'महाराष्ट्राची', 'राजधानी', 'मुंबई', 'आहे.', 'मुंबईत', 'साधारण', '१.८', 'कोटी', 'लोक', 'राहतात.', 'नागपूर', 'शहर', 'महाराष्ट्राची', 'उपराजधानी', 'आहे.', 'मध्ययुगीन', 'महाराष्ट्र', 'सातवाहन', 'राजवंश', 'राष्ट्रकूट', 'राजवंश,', 'पश्चिम', 'चालुक्य,', 'मुघल', 'आणि', 'मराठ्यांच्या', 'साम्राज्याचा', 'समावेश', 'आहे.', 'विस्तार', '१,', '१८,', '८०९', 'चौरस', 'मैल', '(३,०७,'
# ...

# %%
# Problem-1 Count total number of 'the' in this file
# Problem-2 Count and print the names which starts with 'M'

# %%
m = open('maharashtra.txt')

# %%
text = m.read()

# %%
text.count('the') + text.count('The')
# Out:
# 27

# %%
words = text.split()

# %%
count = [1 for word in words if word.startswith('M')]

# %%
sum(count)
# Out:
# 9

# %% [markdown]
# ##### with statement

# %%
with open('sample.txt') as f:
    data = f.read()

# %%
print(data)
# Out:
# Hello Friends!
# How are you?
# Welcome to the world of Python Programming

# %% [markdown]
# ##### Writing in the file

# %%
# mode - 'w' (existing file will be overwritten otherwise created)

# %%
f = open('myfile.txt', 'w')

# %%
f
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='w' encoding='UTF-8'>

# %% [markdown]
# ##### writable() function

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %% [markdown]
# ##### writelines() function

# %%
lines = ['It is raining heavily.','It may cause flood.']

# %%
f.writelines(lines)

# %%
f.close()

# %% [markdown]
# ##### write() function

# %%
sent = 'Python is intepreted language. We need an intepreter to code in it.'

# %%
f = open('myfile.txt', 'w')
f.write(sent)
f.close()

# %%
with open('myfile.txt','w') as f:
    f.write('Hello\n')
    f.write('This is second line.\n')
    f.write('and the last line.')

# %% [markdown]
# ##### Simple file copy operation

# %%
# source file -> sample.txt
# destination file -> mydata.txt

# %%
s = open('sample.txt','r')  
d = open('mydata.txt','w')

# %%
contents = s.read()
d.write(contents)
d.close()

# %% [markdown]
# ##### Appending the data to file

# %%
s = open('sample.txt','a')

# %%
s.write('\nGood bye!')
# Out:
# 10

# %%
s.close()

# %%
s = open('sample.txt','r') 
print(s.read())
# Out:
# Hello Friends!
# How are you?
# Welcome to the world of Python Programming
# Good bye!

# %% [markdown]
# ##### Exclusive creation

# %%
f = open('sample.txt','x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 f = open('sample.txt','x')
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'sample.txt'

# %%
f = open('mytext.txt','x')

# %% [markdown]
# ##### Example

# %% [markdown]
# Given with three text files, count the total of all
# the numerical elements from these files.

# %%
f = open('num1.txt')

# %%
data = f.read()

# %%
data
# Out:
# '23\n54\n12\n67\n39\n81\n50\n88\n97\n33'

# %%
nums = data.split()

# %%
nums
# Out:
# ['23', '54', '12', '67', '39', '81', '50', '88', '97', '33']

# %%
nums = [int(n) for n in nums]

# %%
nums
# Out:
# [23, 54, 12, 67, 39, 81, 50, 88, 97, 33]

# %%
sum(nums)
# Out:
# 544

# %%
f = open('num2.txt')
data = f.read()
data
# Out:
# '45 abc\n67 78 12\nfcdf 34 11\ngh edt hy\n56 \n34 56 7f\n12 64 eeee\n4\n56 67 78 dr\n12 f34 63'

# %%
nums = data.split()

# %%
nums;

# %%
nums = [int(n) for n in nums if n.isdigit()]

# %%
nums
# Out:
# [45, 67, 78, 12, 34, 11, 56, 34, 56, 12, 64, 4, 56, 67, 78, 12, 63]

# %%
sum(nums)
# Out:
# 749

# %% [markdown]
# ##### File position

# %% [markdown]
# The file position (also known as the file pointer or file cursor) refers to the current location within an open file where the next read or write operation will occur.

# %%
f = open('sample.txt')

# %%
f.tell()
# Out:
# 0

# %%
f.readline()
# Out:
# 'Hello Friends!\n'

# %%
f.tell()
# Out:
# 15

# %%
f.readline()
# Out:
# 'How are you?\n'

# %%
f.tell()
# Out:
# 28

# %%
f.readline()
# Out:
# 'Welcome to the world of Python Programming\n'

# %%
f.tell()
# Out:
# 71

# %%
f.readline()
# Out:
# 'Good bye!'

# %%
f.tell()
# Out:
# 80

# %%
f.seek(50)
# Out:
# 50

# %%
f.readline()
# Out:
# 'f Python Programming\n'

# %% [markdown]
# ##### Binary mode

# %% [markdown]
# Opening a file in binary mode means you're telling the interpreter to treat the file's content as a sequence of raw bytes, rather than trying to interpret it as text with a specific character encoding (like UTF-8, ASCII, etc.).

# %% [markdown]
# How to Open a File in Binary Mode:
#
# You add a 'b' to your usual mode:
#
#     'rb': Read binary. Opens the file for reading in binary mode.
#     'wb': Write binary. Opens the file for writing in binary mode. If the file exists, its contents are truncated (emptied). If it doesn't exist, it's created.
#     'ab': Append binary. Opens the file for appending in binary mode. Data is written to the end of the file. If the file doesn't exist, it's created.
#     'r+b': Read and write binary. Opens the file for both reading and writing in binary mode.
#     'w+b': Read and write binary. Opens the file for both reading and writing in binary mode. Truncates the file first.
#     'a+b': Read and write binary. Opens the file for both reading and writing in binary mode. Appends data to the end.

# %%
with open('mydata.bin','wb') as f:
    f.write(b'Hello World!')

# %%
with open('mydata.bin','rb') as f:
    content = f.read()
    print(f'Data in file {content}')
# Out:
# Data in file b'Hello World!'
